# %%
import akshare as ak
ak.stock_zh_a_hist(symbol='601166', period='daily', start_date='20010101', end_date='20240112')
# Out:
#               日期     开盘     收盘     最高     最低      成交量           成交额     振幅  \
# 0     2007-02-05  24.80  22.18  25.00  22.01  1696943  4.023212e+09  18.71
# 1     2007-02-06  22.50  23.81  24.20  21.31   672768  1.579251e+09  13.03
# 2     2007-02-07  23.98  24.96  26.00  23.82   800218  1.990145e+09   9.16
# 3     2007-02-08  24.70  24.41  24.84  23.88   341531  8.311912e+08   3.85
# 4     2007-02-09  24.28  24.01  24.58  23.60   215510  5.167591e+08   4.01
# ...          ...    ...    ...    ...    ...      ...           ...    ...
# 4090  2024-01-08  14.73  14.70  14.90  14.63   705452  1.039082e+09   1.82
# 4091  2024-01-09  14.69  14.68  14.71  14.59   483876  7.090842e+08   0.82
# 4092  2024-01-10  14.66  14.61  14.70  14.61   327007  4.787038e+08   0.61
# 4093  2024-01-11  14.60  14.66  14.73  14.52   414090  6.062612e+08   1.44
# 4094  2024-01-12  14.61  14.69  14.77  14.60   345305  5.072429e+08   1.16
#
#         涨跌幅   涨跌额    换手率
# 0     38.80  6.20  37.65
# ...

# %%
import akshare as ak
ak.stock_new_ipo_cninfo()
# Out:
#         证劵代码  证券简称        上市日期        申购日期    发行价       总发行数量   发行市盈率  \
# 0     001379  腾达科技         NaN  2024-01-09  16.98   5000.0000   26.05
# 1     301502  华阳智能         NaN  2024-01-24    NaN   1427.1000     NaN
# 2     301577  美信科技         NaN  2024-01-15  36.51   1109.5149   25.22
# 3     603082  北自科技         NaN  2024-01-19    NaN   4055.6900     NaN
# 4     603375   盛景微         NaN  2024-01-15  38.18   2516.6667   22.27
# ...      ...   ...         ...         ...    ...         ...     ...
# 1262  605228  神通科技  2021-01-20  2021-01-07   5.89   8000.0000   22.98
# 1263  003035  南网能源  2021-01-19  2021-01-08   1.40  75757.5757   22.88
# 1264  605005  合兴股份  2021-01-19  2021-01-07   6.38   4010.0000   22.96
# 1265  688317  之江生物  2021-01-18  2021-01-06  43.22   4867.6088  189.85
# 1266  688819  天能股份  2021-01-18  2021-01-05  41.79  11660.0000   30.98
#
#        上网发行中签率     摇号结果公告日       中签公告日       中签缴款日  网上申购上限    上网发行数量
# ...

# %%
import redis

import common.supports as supports

r = redis.Redis(host=supports.APP_CONFIG["redis"]["host"], port=6379, db=0, password="123456", decode_responses=True)
r.get('foo')
print("Ok")
r.set()
# Out:
# Ok
